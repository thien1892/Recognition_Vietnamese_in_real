# %% [markdown]
# <a href="https://colab.research.google.com/github/thien1892/Recognition_Vietnamese_in_real/blob/main/sample_craft_and_vietocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Clone code

# %%
# !git clone https://github.com/thien1892/Recognition_Vietnamese_in_real.git
# Out:
# Cloning into 'Recognition_Vietnamese_in_real'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 40 (delta 9), reused 37 (delta 6), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %%
cd Recognition_Vietnamese_in_real/
# Out:
# /content/Recognition_Vietnamese_in_real

# %% [markdown]
# # 2. Cài đặt thư viện liên quan

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # 3. Load pretrain

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1Jsp2v5L69BFkkBnb6f3QSifz7Etd9t9g',
                                    dest_path='./craft_mlt_25k.pth')

gdd.download_file_from_google_drive(file_id='1SrlJmj5UeWHUIhc94cu8YmsRuTTFWbb7',
                                    dest_path='./vietocr.pth')

gdd.download_file_from_google_drive(file_id='1BAqAcX14TCsc83fOX8jn15_8r-hUs7t8',
                                    dest_path='./config.yml')

# %% [markdown]
# #4. Xử lý và dự đoán

# %%
# !python test.py \
 --trained_model=./craft_mlt_25k.pth \
 --trained_model_vietocr=./vietocr.pth \
 --config_vietocr=./config.yml \
 --test_folder=test/ \
 --cuda False
# Out:
# Loading weights from checkpoint (./craft_mlt_25k.pth)
# elapsed time : 16.1212375164032s

# %% [markdown]
# #5. Hiển thị kết quả

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread('result/test.jpg')
img = cv2.resize(img, (600,400))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F0E8E37D250>
